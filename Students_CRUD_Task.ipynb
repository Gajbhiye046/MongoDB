# %%
from  pymongo import MongoClient

# %%
#<password> = me14m052
conn_str = "mongodb://Abhishek046:me14m052@ac-zsvemkc-shard-00-00.iu7rzfa.mongodb.net:27017,ac-zsvemkc-shard-00-01.iu7rzfa.mongodb.net:27017,ac-zsvemkc-shard-00-02.iu7rzfa.mongodb.net:27017/?ssl=true&replicaSet=atlas-uyvmpq-shard-0&authSource=admin&retryWrites=true&w=majority"
Abhi = MongoClient(conn_str, serverSelectionTimeoutMS=5000)

# %%
Abhi
# Out:
# MongoClient(host=['ac-zsvemkc-shard-00-02.iu7rzfa.mongodb.net:27017', 'ac-zsvemkc-shard-00-00.iu7rzfa.mongodb.net:27017', 'ac-zsvemkc-shard-00-01.iu7rzfa.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, ssl=True, replicaset='atlas-uyvmpq-shard-0', authsource='admin', retrywrites=True, w='majority', serverselectiontimeoutms=5000)

# %%
db = Abhi["GUVI"]

# %%
Coll = db["Students"]

# %%
import ujson as ujson
import pandas as pd

records = map(ujson.loads, open('students.json'))
df = pd.DataFrame.from_records(records, index = '_id')

# %%
df
# Out:
#                  name                                             scores
# _id
# 0          aimee Zank  [{'score': 1.463179736705023, 'type': 'exam'},...
# 1    Aurelia Menendez  [{'score': 60.06045071030959, 'type': 'exam'},...
# 2         Corliss Zuk  [{'score': 67.03077096065002, 'type': 'exam'},...
# 3          Bao Ziglar  [{'score': 71.64343899778332, 'type': 'exam'},...
# 4    Zachary Langlais  [{'score': 78.68385091304332, 'type': 'exam'},...
# ..                ...                                                ...
# 195     Linnie Weigel  [{'score': 52.44578368517977, 'type': 'exam'},...
# 196  Santiago Dollins  [{'score': 52.04052571137036, 'type': 'exam'},...
# 197     Tonisha Games  [{'score': 38.51269589995049, 'type': 'exam'},...
# 198    Timothy Harrod  [{'score': 11.9075674046519, 'type': 'exam'}, ...
# 199        Rae Kohout  [{'score': 82.11742562118049, 'type': 'exam'},...
#
# [200 rows x 2 columns]

# %%
pd.DataFrame.from_records(df['scores'])
# Out:
#                                                 0  \
# 0    {'score': 1.463179736705023, 'type': 'exam'}
# 1    {'score': 60.06045071030959, 'type': 'exam'}
# 2    {'score': 67.03077096065002, 'type': 'exam'}
# 3    {'score': 71.64343899778332, 'type': 'exam'}
# 4    {'score': 78.68385091304332, 'type': 'exam'}
# ..                                            ...
# 195  {'score': 52.44578368517977, 'type': 'exam'}
# 196  {'score': 52.04052571137036, 'type': 'exam'}
# 197  {'score': 38.51269589995049, 'type': 'exam'}
# 198   {'score': 11.9075674046519, 'type': 'exam'}
# 199  {'score': 82.11742562118049, 'type': 'exam'}
#
#                                                 1  \
# 0    {'score': 11.78273309957772, 'type': 'quiz'}
# 1    {'score': 52.79790691903873, 'type': 'quiz'}
# 2    {'score': 6.301851677835235, 'type': 'quiz'}
# 3    {'score': 24.80221293650313, 'type': 'quiz'}
# 4     {'score': 90.2963101368042, 'type': 'quiz'}
# ..                                            ...
# ...

# %%
import json
data = [json.loads(line) for line in open('students.json', 'r')]

# %%
data
# Out:
# [{'_id': 0,
#   'name': 'aimee Zank',
#   'scores': [{'score': 1.463179736705023, 'type': 'exam'},
#    {'score': 11.78273309957772, 'type': 'quiz'},
#    {'score': 35.8740349954354, 'type': 'homework'}]},
#  {'_id': 1,
#   'name': 'Aurelia Menendez',
#   'scores': [{'score': 60.06045071030959, 'type': 'exam'},
#    {'score': 52.79790691903873, 'type': 'quiz'},
#    {'score': 71.76133439165544, 'type': 'homework'}]},
#  {'_id': 2,
#   'name': 'Corliss Zuk',
#   'scores': [{'score': 67.03077096065002, 'type': 'exam'},
#    {'score': 6.301851677835235, 'type': 'quiz'},
#    {'score': 66.28344683278382, 'type': 'homework'}]},
#  {'_id': 3,
#   'name': 'Bao Ziglar',
#   'scores': [{'score': 71.64343899778332, 'type': 'exam'},
#    {'score': 24.80221293650313, 'type': 'quiz'},
#    {'score': 42.26147058804812, 'type': 'homework'}]},
#  {'_id': 4,
#   'name': 'Zachary Langlais',
#   'scores': [{'score': 78.68385091304332, 'type': 'exam'},
#    {'score': 90.2963101368042, 'type': 'quiz'},
# ...

# %%
#Coll.insert_many(data)

# %%
Abhi.list_database_names()
# Out:
# ['Abhishek',
#  'GUVI',
#  'Share',
#  'sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_guides',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'admin',
#  'local']

# %%
db.list_collection_names()
# Out:
# ['Data', 'Students']

# %% [markdown]
# ##### Mongo Atlas search query :
#     {$and : [{'scores.0.score' : {$gte : 40}},{'scores.0.score' : {$lte : 70}} ]}

# %% [markdown]
#    ### Sample query stages, May not work - for reference
#         lst_1 =[]
#         pipeline = [ {'$match' :  {'scores.0.score': {'$gte': 40 } } },
#                      { '$unwind': "$scores" },
#                      {'$group' : {'_id': '$scores.type','Exam_score': {'$avg' : '$scores.score' }} }
#                      {'$match' :  {'scores.0.score': {'$gte': '$Exam_score' } } },
#                     # {'$sortArray': { 'input': "$scores", 'sortBy': { '0.score': 1 } } },
#                      {"$project": {'_id': 1,'name': 1,'scores.0.score': 1} }
#                    ]
#         for i in Coll.aggregate(pipeline) :
#                 lst_1.append(i)

# %%
lst_1
# Out:
# []

# %% [markdown]
# #### 2) Find students who scored below average in the exam and pass mark is 40%?

# %%
lst_av_score_per_cat =[]
pipeline_2 = [{ '$unwind': "$scores" },
              {'$group' : {'_id': '$scores.type','Avg_score': {'$avg' : '$scores.score' }} },
              {"$project": {'_id': 1,'name': 1,'Avg_score' :  { '$trunc': [ "$Avg_score", 3 ]} }}
              ]
for i in Coll.aggregate(pipeline_2) :
    lst_av_score_per_cat.append(i)

# %% [markdown]
# ##### Calulate average marks by grouping scores based on 'type'

# %%
lst_av_score_per_cat
# Out:
# [{'_id': 'homework', 'Avg_score': 67.818},
#  {'_id': 'quiz', 'Avg_score': 48.996},
#  {'_id': 'exam', 'Avg_score': 48.673}]

# %%
coll_av =db['Students_average_score']

# %%
lst =[]
pipeline_3 = [{'$match':{'scores.0.score': {'$lte': 48.674 },'scores.0.score': {'$gte': 40 } }},
               #{'$unwind': "$scores"},
               {"$project": {'_id': 1,'name': 1,'scores': 1
                            } }
              ]
for i in Coll.aggregate(pipeline_3) :
    lst.append(i)

# %%
len(lst)
# Out:
# 119

# %%
lst
# Out:
# [{'_id': 7,
#   'name': 'Salena Olmos',
#   'scores': [{'score': 90.37826509157176, 'type': 'exam'},
#    {'score': 42.48780666956811, 'type': 'quiz'},
#    {'score': 96.52986171633331, 'type': 'homework'}]},
#  {'_id': 24,
#   'name': 'Jesusa Rickenbacker',
#   'scores': [{'score': 86.0319702155683, 'type': 'exam'},
#    {'score': 1.967495200433389, 'type': 'quiz'},
#    {'score': 61.10861071547914, 'type': 'homework'}]},
#  {'_id': 44,
#   'name': 'Houston Valenti',
#   'scores': [{'score': 98.06441387027331, 'type': 'exam'},
#    {'score': 0.8760893342659504, 'type': 'quiz'},
#    {'score': 15.2177618920215, 'type': 'homework'}]},
#  {'_id': 59,
#   'name': 'Vinnie Auerbach',
#   'scores': [{'score': 95.45508256300009, 'type': 'exam'},
#    {'score': 7.512188017365151, 'type': 'quiz'},
#    {'score': 28.5905754294006, 'type': 'homework'}]},
#  {'_id': 61,
#   'name': 'Grady Zemke',
#   'scores': [{'score': 51.91561300267121, 'type': 'exam'},
# ...

# %% [markdown]
# #### 4) Find the total and average of the exam, quiz and homework and store them in a separate collection.

# %% [markdown]
# ##### Sorting students based on total scores (exam,homework,quiz)

# %%
lst =[]
pipeline_4 = [{ '$unwind': "$scores" },
              {'$group' : {'_id': {'name_id':'$_id', 'name':'$name'},'Total_score': {'$sum' : '$scores.score' }} },
              {'$sort' : {'Total_score':-1}},
              {"$project": {'_id': 1,'name': 1,'Total_score': { '$trunc': [ "$Total_score", 3 ]}} } 
              #{'$limit' : 10}
              ]
for i in Coll.aggregate(pipeline_4) :
    lst.append(i)

# %% [markdown]
# ##### Total of the exam,quiz and homework of all the students

# %%
lst
# Out:
# [{'_id': {'name_id': 13, 'name': 'Jessika Dagenais'}, 'Total_score': 275.949},
#  {'_id': {'name_id': 64, 'name': 'Whitley Fears'}, 'Total_score': 268.646},
#  {'_id': {'name_id': 52, 'name': 'Tawana Oberg'}, 'Total_score': 266.995},
#  {'_id': {'name_id': 127, 'name': 'Jessika Dagenais'}, 'Total_score': 263.398},
#  {'_id': {'name_id': 32, 'name': 'Gwen Honig'}, 'Total_score': 263.266},
#  {'_id': {'name_id': 191, 'name': 'Efrain Claw'}, 'Total_score': 252.833},
#  {'_id': {'name_id': 159, 'name': 'Terica Brugger'}, 'Total_score': 251.404},
#  {'_id': {'name_id': 11, 'name': 'Marcus Blohm'}, 'Total_score': 248.509},
#  {'_id': {'name_id': 104, 'name': 'Brittny Warwick'}, 'Total_score': 247.513},
#  {'_id': {'name_id': 182, 'name': 'Jenise Mcguffie'}, 'Total_score': 247.055},
#  {'_id': {'name_id': 98, 'name': 'Carli Ector'}, 'Total_score': 244.827},
#  {'_id': {'name_id': 55, 'name': 'Tresa Sinha'}, 'Total_score': 244.502},
# ...

# %%
# Run only once for creation of collection
coll_tot =db['Students_total_score']

# %%
# Data insertion on 'Students_total_score' collection
coll_tot.insert_many(lst)

# %% [markdown]
# #### 1) Find the student name who scored maximum scores in all (exam, quiz and homework)?
#     'name_id': 13, 'name': 'Jessika Dagenais', 'Total_score': 275.949

# %% [markdown]
# ##### Average of the exam,quiz and homework of all the students

# %%
lst =[]
pipeline_5 = [{ '$unwind': "$scores" },
              {'$group' : {'_id': {'name_id':'$_id', 'name':'$name'},'Average_score': {'$avg' : '$scores.score' }} },
              {"$project": {'_id': 1,'name': 1,'Avg_score' :  { '$trunc': [ "$Average_score", 3 ]} }}
              ]
for i in Coll.aggregate(pipeline_5) :
    lst.append(i)

# %%
lst
# Out:
# [{'_id': {'name_id': 179, 'name': 'Gena Riccio'}, 'Avg_score': 67.054},
#  {'_id': {'name_id': 164, 'name': 'Alica Pasley'}, 'Avg_score': 55.21},
#  {'_id': {'name_id': 90, 'name': 'Osvaldo Hirt'}, 'Avg_score': 61.845},
#  {'_id': {'name_id': 78, 'name': 'Len Treiber'}, 'Avg_score': 38.981},
#  {'_id': {'name_id': 156, 'name': 'Kayce Kenyon'}, 'Avg_score': 48.262},
#  {'_id': {'name_id': 27, 'name': 'Edgar Sarkis'}, 'Avg_score': 27.552},
#  {'_id': {'name_id': 14, 'name': 'Alix Sherrill'}, 'Avg_score': 39.496},
#  {'_id': {'name_id': 29, 'name': 'Gwyneth Garling'}, 'Avg_score': 50.67},
#  {'_id': {'name_id': 61, 'name': 'Grady Zemke'}, 'Avg_score': 65.78},
#  {'_id': {'name_id': 170, 'name': 'Danika Loeffler'}, 'Avg_score': 59.303},
#  {'_id': {'name_id': 186, 'name': 'Leonida Lafond'}, 'Avg_score': 32.819},
#  {'_id': {'name_id': 127, 'name': 'Jessika Dagenais'}, 'Avg_score': 87.799},
#  {'_id': {'name_id': 198, 'name': 'Timothy Harrod'}, 'Avg_score': 32.427},
# ...

# %%
coll_av = db['Students_average_score']

# %%
# Data insertion on 'Students_total_score' collection
coll_av.insert_many(lst)

# %% [markdown]
# ##### Maximum value of the exam,quiz and homework of all the students

# %%
lst =[]
pipeline_5 = [{ '$unwind': "$scores" },
              {'$group' : {'_id': '$scores.type','Max_Marks': {'$max' : '$scores.score' }} },
              {"$project": {'_id': 1,'name': 1,'Maximum_Marks': { '$trunc': [ "$Max_Marks", 3 ]}} }
              ]
for i in Coll.aggregate(pipeline_5) :
    lst.append(i)

# %%
lst
# Out:
# [{'_id': 'homework', 'Maximum_Marks': 99.772},
#  {'_id': 'quiz', 'Maximum_Marks': 99.803},
#  {'_id': 'exam', 'Maximum_Marks': 99.336}]

# %%
lst =[]
pipeline_6 = [{ '$unwind': "$scores" },
              {'$group' : {'_id': '$scores.type','Minimum_Marks': {'$min' : '$scores.score' }} },
              {"$project": {'_id': 1,'name': 1,'Minimum_Marks':  { '$trunc': [ "$Minimum_Marks", 3 ]}} }
              ]
for i in Coll.aggregate(pipeline_6) :
    lst.append(i)

# %% [markdown]
# ##### Minimum value of the exam,quiz and homework of all the students

# %%
lst
# Out:
# [{'_id': 'exam', 'Minimum_Marks': 0.043},
#  {'_id': 'quiz', 'Minimum_Marks': 0.006},
#  {'_id': 'homework', 'Minimum_Marks': 11.75}]

# %% [markdown]
# #### 3) Find students who scored below pass mark and assigned them as fail, and above pass mark as pass in all the categories.

# %% [markdown]
#     { $cond: { if: <boolean-expression>, then: <true-case>, else: <false-case> } }
#
#  or
#
#     { $cond: [ <boolean-expression>, <true-case>, <false-case> ] }

# %% [markdown]
# for equality format
#
#     { <field>: { $eq: <value> } }

# %%
# url Reference : https://stackoverflow.com/questions/22107770/use-of-cond-and-eq-with-a-array-of-objects
# $switch url reference : https://www.mongodb.com/docs/manual/reference/operator/aggregation/switch/
lst =[]
pipeline_8 = [{ '$unwind': '$scores' },
              { "$project" :{  "_id" : 1,
                                "name":1,
                                "scores" :1,
                                 'Exam': {'$cond': [{'$eq': ['$scores.type', 'exam']},'$scores', 'null'] },
                                 'Quiz': {'$cond': [{'$eq': ['$scores.type', 'quiz']},'$scores','null']},
                                 'Homework': {'$cond':[{'$eq': ['$scores.type', 'homework']},'$scores','null']}
                   
                                     }},
              {'$group': {
                          '_id': '$_id',
                          'name':{'$first' : '$name'},
                          'Exam': { '$max': '$Exam' },
                          'Quiz': { '$max': '$Quiz' } ,
                          'Homework': { '$max': '$Homework' } 
                          
                     }},
              {'$project': {
                          '_id': 1,
                          'name':1,
                          'Exam': '$Exam',
                          'Quiz': '$Quiz',
                          'Homework': '$Homework'
                          
                     }},
              {
                '$project':
                  { '_id' : 1,
                    "name" : 1,
                   'Exam': '$Exam.score',
                   'Quiz': '$Quiz.score',
                   'Homework': '$Homework.score',
                    "Result" :
                    {
                      '$switch':
                        {
                          'branches': [
                            {
                              'case': { '$or' : [ { '$lte' : [ "$Exam.score" , 40 ] },
                                               { '$lte' : [ "$Quiz.score" , 40 ] },
                                               { '$lte' : [ "$Homework.score" , 40 ] } ] },
                             'then': "Fail."
                            },
                            {
                            'case': { '$and' : [ { '$gte' : [ "$Exam.score" , 75 ] },
                                               { '$gte' : [ "$Quiz.score" , 75 ] },
                                               { '$gte' : [ "$Homework.score" , 75 ] } ] },
                              'then': "Passed with distinction"
                            },
                          ],
                          'default': "Pass"
                        }
                     }
                  }
                },
              {'$sort' : {'name':1}}]
for i in Coll.aggregate(pipeline_8):
    lst.append(i)

# %%
lst
# Out:
# [{'_id': 113,
#   'name': '',
#   'Exam': 77.57315913088024,
#   'Quiz': 13.28135073340091,
#   'Homework': 67.27527802263116,
#   'Result': 'Fail.'},
#  {'_id': 76,
#   'name': 'Adrien Renda',
#   'Exam': 57.24794864351232,
#   'Quiz': 19.5118228072558,
#   'Homework': 70.71043448913191,
#   'Result': 'Fail.'},
#  {'_id': 190,
#   'name': 'Adrien Renda',
#   'Exam': 64.16109192679477,
#   'Quiz': 66.93730600935531,
#   'Homework': 96.0560340227047,
#   'Result': 'Pass'},
#  {'_id': 41,
#   'name': 'Aleida Elsass',
#   'Exam': 28.02518041693717,
#   'Quiz': 95.25243105389065,
#   'Homework': 68.05980405338909,
#   'Result': 'Fail.'},
#  {'_id': 155,
#   'name': 'Aleida Elsass',
#   'Exam': 42.89558347656537,
#   'Quiz': 94.10647660402866,
#   'Homework': 30.56402201379193,
#   'Result': 'Fail.'},
#  {'_id': 164,
#   'name': 'Alica Pasley',
#   'Exam': 41.3852820348269,
#   'Quiz': 87.0183839032626,
#   'Homework': 37.22917544696978,
#   'Result': 'Fail.'},
#  {'_id': 50,
# ...

# %% [markdown]
# #### 5) Create a new collection which consists of students who scored below average and above 40% in all the categories.

# %%
# Avergae scores per category among all students
lst_av_score_per_cat
# Out:
# [{'_id': 'homework', 'Avg_score': 67.818},
#  {'_id': 'quiz', 'Avg_score': 48.996},
#  {'_id': 'exam', 'Avg_score': 48.673}]

# %% [markdown]
# ##### Sample Document from Students dataset
# ![image.png](attachment:image.png)

# %%
lst =[]
pipeline_9 = [  {'$match' : { '$and': [ { "scores.0.score" : {'$gte' : 40} },
                                     { "scores.1.score" : {'$gte' : 40} },
                                     { "scores.2.score" : {'$gte' : 40} } ] } },
               {'$match':{ '$and' : [{'scores.0.score': {'$lte': 48.674 } },
                                      {'scores.1.score': {'$lte': 48.97 } },
                                      { 'scores.2.score': {'$lte': 67.819 } } ]} },
              {'$sort' : {'name':1}},
              {"$project": {'_id': 1,'name': 1,'scores':  -1 }}
              ]
for i in Coll.aggregate(pipeline_10) :
    lst.append(i)

# %%
lst
# Out:
# []

# %% [markdown]
# #### 6) Create a new collection which consists of students who scored below the fail mark in all the categories.

# %%
lst =[]
pipeline_10 = [
              {'$match' : { '$and': [ { "scores.0.score" : {'$lte' : 40} },
                                     { "scores.1.score" : {'$lte' : 40} },
                                     { "scores.2.score" : {'$lte' : 40} } ] } },
              {'$sort' : {'name':1}},
              {"$project": {'_id': 1,'name': 1,'scores':  -1 }}
              ]
for i in Coll.aggregate(pipeline_10) :
    lst.append(i)

# %%
lst
# Out:
# [{'_id': 0,
#   'name': 'aimee Zank',
#   'scores': [{'score': 1.463179736705023, 'type': 'exam'},
#    {'score': 11.78273309957772, 'type': 'quiz'},
#    {'score': 35.8740349954354, 'type': 'homework'}]}]

# %%
# Command to drop the collection 
#coll_all_fail.drop()

# %%
coll_all_fail = db['Students_all_category_fail']
# Data insertion on Collection
coll_all_fail.insert_many(lst)

# %% [markdown]
# #### 7) Create a new collection which consists of students who scored above pass mark in all the categories.

# %%
lst =[]
pipeline_11 = [
              {'$match' : { '$and': [ { "scores.0.score" : {'$gte' : 40} },
                                     { "scores.1.score" : {'$gte' : 40} },
                                     { "scores.2.score" : {'$gte' : 40} } ] } },
              {'$sort' : {'name':1}},
              {"$project": {'_id': 1,'name': 1,'scores':  -1 }}
              ]
for i in Coll.aggregate(pipeline_11) :
    lst.append(i)

# %%
lst
# Out:
# [{'_id': 190,
#   'name': 'Adrien Renda',
#   'scores': [{'score': 64.16109192679477, 'type': 'exam'},
#    {'score': 66.93730600935531, 'type': 'quiz'},
#    {'score': 96.0560340227047, 'type': 'homework'}]},
#  {'_id': 1,
#   'name': 'Aurelia Menendez',
#   'scores': [{'score': 60.06045071030959, 'type': 'exam'},
#    {'score': 52.79790691903873, 'type': 'quiz'},
#    {'score': 71.76133439165544, 'type': 'homework'}]},
#  {'_id': 104,
#   'name': 'Brittny Warwick',
#   'scores': [{'score': 69.54399888097534, 'type': 'exam'},
#    {'score': 82.00469934215849, 'type': 'quiz'},
#    {'score': 95.96446106607902, 'type': 'homework'}]},
#  {'_id': 98,
#   'name': 'Carli Ector',
#   'scores': [{'score': 88.18040268522668, 'type': 'exam'},
#    {'score': 60.3111085581054, 'type': 'quiz'},
#    {'score': 96.33612053785647, 'type': 'homework'}]},
#  {'_id': 116,
#   'name': 'Corliss Zuk',
#   'scores': [{'score': 76.45468797439878, 'type': 'exam'},
# ...

# %%
len(lst)
# Out:
# 54

# %%
coll_all_pass = db['Students_all_category_pass']
# Data insertion on Collection
coll_all_pass.insert_many(lst)
